# %% [markdown]
# Objectif : transcrire les extraits audios en texte

# %%
import whisper
import os

model = whisper.load_model("base")  # petit modèle rapide, tu peux choisir "small", "medium", "large"
input_folder = "../Audios/Original_files"
output_folder = "../Transcriptions"

for filename in os.listdir(input_folder):
    if filename.endswith(".mp3"):
        audio_path = os.path.join(input_folder, filename)
        transcription_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")

        result = model.transcribe(audio_path)
        text = result["text"]

        with open(transcription_path, "w", encoding="utf-8") as f:
            f.write(text)

        print(f"{filename} transcrit : {text}")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Rabbit And Crow | One Minute Story | Childenzia English Story.mp3 transcrit :  Rabbit and Crow, a one minute story. Once upon a time, there was a rabbit. He always tried to copy other animals. One day he saw a crow. The crow was sitting on a tree and doing nothing. Rabbit thought to do the same. He said on the ground and doing nothing when a fox saw him. Fox came near and ate him. For a lot of the stories, do sit and do nothing you need to be on top.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...
